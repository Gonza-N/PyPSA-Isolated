# %% [markdown]
# # Cutouts and Capacity Factors (2016-2025)
#
# This notebook creates ERA5 cutouts (.nc) for 2016-2025 and computes wind/solar capacity factors using the same workflow as `config.py` and `case_analysis.ipynb`.
#
# Important:
# - Set `GENERATE_CUTOUTS = True` only when you want to create missing .nc files.
# - Keep it `False` for analysis-only runs.

# %%
import importlib
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# ── CRITICAL: Disable distributed scheduler before importing config ──────────
# This avoids SSL certificate corruption errors on Windows when atlite uses dask
import os
import sys
sys.modules['distributed'] = None
import dask
dask.config.set(scheduler='synchronous')
os.environ['DASK_DISTRIBUTED__DISABLE'] = 'true'
# ──────────────────────────────────────────────────────────────────────────────

import config
config = importlib.reload(config)

# -------- User parameters --------
CASE_FOLDER = "input_punta_arenas"
CASE_NAME = "magallanes"
YEARS = list(range(2000, 2025))

# Turn on only when you need to create/update .nc files
GENERATE_CUTOUTS = False
OVERWRITE_EXISTING_CUTOUTS = False

# VRE method and technology assumptions (same family as case_analysis.ipynb)
VRE_METHOD = "atlite_technology"
WIND_TURBINE = "Vestas_V112_3MW"
SOLAR_PANEL = "CSi"
SOLAR_ORIENTATION = "latitude_optimal"

# Preferred target grid for new consistent cutouts
DX = 0.25
DY = 0.25

# Grid locking mode:
# - "fixed_bounds": fixed geographic box (used here for full Magallanes)
# - "match_existing_year": force all years to match one existing cutout
# - "use_nodes_bounds": use nodes +/-1 deg with DX,DY above
GRID_LOCK_MODE = "fixed_bounds"
FIXED_BOUNDS = (-76.0, -66.0, -56.0, -50.0)  # Full Magallanes
REFERENCE_YEAR_FOR_GRID = 2019

DATA_DIR = Path("data")
DATA_DIR.mkdir(exist_ok=True)

print(f"Case: {CASE_NAME}")
print(f"Years: {YEARS[0]}-{YEARS[-1]}")
print(f"Generate cutouts: {GENERATE_CUTOUTS}")
print(f"Overwrite existing cutouts: {OVERWRITE_EXISTING_CUTOUTS}")
print(f"Grid lock mode: {GRID_LOCK_MODE}")
# Out:
# Case: magallanes
# Years: 2000-2014
# Generate cutouts: True
# Overwrite existing cutouts: False
# Grid lock mode: fixed_bounds

# %%
import numpy as np
import xarray as xr

paths = config.get_case_paths(CASE_FOLDER)
nodes_df = config.load_nodes_from_csv(paths["csv_nodes"])
if nodes_df is None or nodes_df.empty:
    raise ValueError("Nodes CSV is empty or missing.")

if not {"lat", "lon"}.issubset(nodes_df.columns):
    raise ValueError("Nodes CSV must include lat and lon columns.")

valid_coords = nodes_df[["lat", "lon"]].dropna()
if valid_coords.empty:
    raise ValueError("No valid lat/lon coordinates found in nodes CSV.")

padding_deg = 1.0
lon_min = float(valid_coords["lon"].min()) - padding_deg
lon_max = float(valid_coords["lon"].max()) + padding_deg
lat_min = float(valid_coords["lat"].min()) - padding_deg
lat_max = float(valid_coords["lat"].max()) + padding_deg
derived_bounds = (lon_min, lon_max, lat_min, lat_max)

# Resolve canonical grid once, then reuse for all years.
if GRID_LOCK_MODE == "fixed_bounds":
    lock_bounds = tuple(float(v) for v in FIXED_BOUNDS)
    lock_dx = float(DX)
    lock_dy = float(DY)
elif GRID_LOCK_MODE == "match_existing_year":
    ref_path = DATA_DIR / f"{CASE_NAME}_{REFERENCE_YEAR_FOR_GRID}.nc"
    if not ref_path.exists():
        raise FileNotFoundError(
            f"Reference cutout not found for grid lock mode: {ref_path}"
        )
    with xr.open_dataset(ref_path) as ds_ref:
        x_vals = np.array(ds_ref["x"].values)
        y_vals = np.array(ds_ref["y"].values)
        lon_min_lock = float(np.min(x_vals))
        lon_max_lock = float(np.max(x_vals))
        lat_min_lock = float(np.min(y_vals))
        lat_max_lock = float(np.max(y_vals))
        dx_lock = float(np.median(np.diff(np.sort(np.unique(x_vals)))))
        dy_lock = float(np.median(np.diff(np.sort(np.unique(y_vals)))))

    lock_bounds = (lon_min_lock, lon_max_lock, lat_min_lock, lat_max_lock)
    lock_dx = dx_lock
    lock_dy = dy_lock
else:
    lock_bounds = derived_bounds
    lock_dx = float(DX)
    lock_dy = float(DY)

print("Nodes used for VRE profiles:")
display(nodes_df[["zone", "lat", "lon"]])

print("\nDerived bounds from nodes (+/-1 deg):")
print(f"lon_min={lon_min:.4f}, lon_max={lon_max:.4f}, lat_min={lat_min:.4f}, lat_max={lat_max:.4f}")

print("\nCanonical grid to use for all generated years:")
print(f"bounds={lock_bounds}")
print(f"dx={lock_dx}, dy={lock_dy}")
# Out:
# Nodes used for VRE profiles:
#                   zone     lat     lon
# 0  punta_arenas_centro -53.163 -70.917
# 1           cabo_negro -52.966 -70.829
# Derived bounds from nodes (+/-1 deg):
# lon_min=-71.9170, lon_max=-69.8290, lat_min=-54.1630, lat_max=-51.9660
#
# Canonical grid to use for all generated years:
# bounds=(-76.0, -66.0, -56.0, -50.0)
# dx=0.25, dy=0.25

# %%
# ── Connectivity & credentials diagnostic ─────────────────────────────────────
import subprocess, socket, urllib.request, json, os, time

print("=" * 60)
print("1. DNS resolution — cds.climate.copernicus.eu")
try:
    ip = socket.gethostbyname("cds.climate.copernicus.eu")
    print(f"   OK  → {ip}")
except Exception as e:
    print(f"   FAIL → {e}")

print()
print("2. HTTP GET — CDS API root (5 s timeout)")
try:
    t0 = time.time()
    with urllib.request.urlopen("https://cds.climate.copernicus.eu/api", timeout=5) as r:
        print(f"   OK  → HTTP {r.status}  ({time.time()-t0:.1f}s)")
except Exception as e:
    print(f"   FAIL → {e}")

print()
print("3. CDS API credentials (~/.cdsapirc)")
cdsapirc = os.path.expanduser("~/.cdsapirc")
if os.path.exists(cdsapirc):
    with open(cdsapirc) as f:
        lines = f.read().splitlines()
    for line in lines:
        if line.startswith("key"):
            # mask key value, show only first 6 chars
            parts = line.split(":", 1)
            val = parts[1].strip() if len(parts) > 1 else ""
            masked = val[:6] + "****" if len(val) > 6 else "****"
            print(f"   key: {masked}")
        else:
            print(f"   {line}")
else:
    print("   MISSING — create ~/.cdsapirc with url and key")

print()
print("4. Quick cdsapi ping (actual API call, 10 s timeout)")
try:
    import cdsapi
    c = cdsapi.Client(quiet=True, wait_until_complete=False, retry_max=1)
    print("   Client created OK")
except Exception as e:
    print(f"   FAIL → {e}")

print("=" * 60)
# Out:
# ============================================================
# 1. DNS resolution — cds.climate.copernicus.eu
#    OK  → 136.156.139.54
#
# 2. HTTP GET — CDS API root (5 s timeout)
#    FAIL → [ASN1: NOT_ENOUGH_DATA] not enough data (_ssl.c:4057)
#
# 3. CDS API credentials (~/.cdsapirc)
#    url: https://cds.climate.copernicus.eu/api
#    key: a730a8****
#
# 4. Quick cdsapi ping (actual API call, 10 s timeout)
#    Client created OK
# ============================================================

# %%
# Quick CDS credentials check (without download)
import os
import cdsapi

cdsapirc_path = os.path.expanduser("~/.cdsapirc")

if os.path.exists(cdsapirc_path):
    try:
        # Just initialize - don't download
        client = cdsapi.Client(quiet=True, retry_max=1, timeout=10)
        print("OK: CDS credentials file exists and client initialized")
    except Exception as e:
        print(f"FAIL: {str(e)[:100]}")
else:
    print("FAIL: ~/.cdsapirc not found")
# Out:
# OK: CDS credentials file exists and client initialized

# %%
# Validation of generated cutouts (existence, size, readability, metadata)
import xarray as xr

years_check = [2016, 2017, 2018, 2019]
rows = []

for y in years_check:
    p = DATA_DIR / f"{CASE_NAME}_{y}.nc"
    rec = {
        "year": y,
        "exists": p.exists(),
        "size_MB": None,
        "open_ok": False,
        "time_len": None,
        "x_len": None,
        "y_len": None,
        "time_start": None,
        "time_end": None,
        "n_data_vars": None,
    }

    if p.exists():
        rec["size_MB"] = p.stat().st_size / (1024**2)
        try:
            with xr.open_dataset(p) as ds:
                rec["open_ok"] = True
                rec["time_len"] = int(ds.sizes.get("time", 0))
                rec["x_len"] = int(ds.sizes.get("x", 0))
                rec["y_len"] = int(ds.sizes.get("y", 0))
                rec["n_data_vars"] = int(len(ds.data_vars))
                if "time" in ds.coords and ds.sizes.get("time", 0) > 0:
                    rec["time_start"] = str(ds["time"].values[0])
                    rec["time_end"] = str(ds["time"].values[-1])
        except Exception as e:
            rec["open_ok"] = False
            rec["time_start"] = f"ERROR: {e}"

    rows.append(rec)

check_df = pd.DataFrame(rows)

print("Cutout validation (2016-2019):")
display(check_df)

ok_files = check_df[(check_df["exists"]) & (check_df["open_ok"])].copy()
if not ok_files.empty:
    min_mb = ok_files["size_MB"].min()
    max_mb = ok_files["size_MB"].max()
    ratio = (max_mb / min_mb) if min_mb and min_mb > 0 else None
    print(f"Size range among valid files: {min_mb:.2f} MB to {max_mb:.2f} MB")
    if ratio is not None:
        print(f"Max/min size ratio: {ratio:.3f}")

    same_grid = ok_files[["x_len", "y_len"]].nunique().max() == 1
    print(f"Same spatial grid across valid files: {same_grid}")

    same_time_len = ok_files["time_len"].nunique() == 1
    print(f"Same number of timesteps across valid files: {same_time_len}")
else:
    print("No valid files found to compare.")
# Out:
# Cutout validation (2016-2019):
#    year  exists     size_MB  open_ok  time_len  x_len  y_len  \
# 0  2016    True  313.890235     True      8784     41     25
# 1  2017    True  313.225304     True      8760     41     25
# 2  2018    True  313.418809     True      8760     41     25
# 3  2019    True  313.209021     True      8760     41     25
#
#                       time_start                       time_end  n_data_vars
# 0  2016-01-01T00:00:00.000000000  2016-12-31T23:00:00.000000000           15
# 1  2017-01-01T00:00:00.000000000  2017-12-31T23:00:00.000000000           15
# 2  2018-01-01T00:00:00.000000000  2018-12-31T23:00:00.000000000           15
# 3  2019-01-01T00:00:00.000000000  2019-12-31T23:00:00.000000000           15
# Size range among valid files: 313.21 MB to 313.89 MB
# Max/min size ratio: 1.002
# Same spatial grid across valid files: True
# Same number of timesteps across valid files: False

# %%
# Compare spatial extent/resolution across cutouts
import numpy as np

extent_rows = []
for y in YEARS:
    p = DATA_DIR / f"{CASE_NAME}_{y}.nc"
    if not p.exists():
        continue

    with xr.open_dataset(p) as ds:
        x_vals = np.array(ds["x"].values)
        y_vals = np.array(ds["y"].values)
        extent_rows.append({
            "year": y,
            "x_min": float(np.min(x_vals)),
            "x_max": float(np.max(x_vals)),
            "y_min": float(np.min(y_vals)),
            "y_max": float(np.max(y_vals)),
            "dx_inferred": float(np.median(np.diff(np.sort(np.unique(x_vals))))) if len(np.unique(x_vals)) > 1 else np.nan,
            "dy_inferred": float(np.median(np.diff(np.sort(np.unique(y_vals))))) if len(np.unique(y_vals)) > 1 else np.nan,
            "x_len": int(len(np.unique(x_vals))),
            "y_len": int(len(np.unique(y_vals))),
        })

extent_df = pd.DataFrame(extent_rows)
print("Spatial extent/resolution by year:")

if extent_df.empty:
    print("No cutout files found yet. Run the generation cell first or set GENERATE_CUTOUTS = True.")
else:
    extent_df = extent_df.sort_values("year")
    display(extent_df)

    reference = extent_df.iloc[0]
    same_extent = (
        (extent_df["x_min"] == reference["x_min"]).all()
        and (extent_df["x_max"] == reference["x_max"]).all()
        and (extent_df["y_min"] == reference["y_min"]).all()
        and (extent_df["y_max"] == reference["y_max"]).all()
    )
    same_resolution = (
        np.isclose(extent_df["dx_inferred"], reference["dx_inferred"]).all()
        and np.isclose(extent_df["dy_inferred"], reference["dy_inferred"]).all()
    )
    print(f"All years have same extent: {same_extent}")
    print(f"All years have same resolution: {same_resolution}")
# Out:
# Spatial extent/resolution by year:
# No cutout files found yet. Run the generation cell first or set GENERATE_CUTOUTS = True.

# %%
# Dask already configured in cell 2 for synchronous mode
# (This cell kept for reference; actual setup is at the top of the notebook)

# %%
# Progress monitoring: log start time and track cutout generation
import time
start_time = time.time()

def log_progress(msg):
    elapsed = time.time() - start_time
    print(f"[{elapsed:.1f}s] {msg}")

log_progress("Ready to generate cutouts")
# Out:
# [0.0s] Ready to generate cutouts

# %%
existing = []
created = []
missing = []

log_progress(f"Starting cutout generation for {len(YEARS)} years")

for i, year in enumerate(YEARS):
    log_progress(f"Processing year {year} ({i+1}/{len(YEARS)})")
    
    cutout_file = DATA_DIR / f"{CASE_NAME}_{year}.nc"
    exists_before = cutout_file.exists()

    if GENERATE_CUTOUTS:
        force_prepare = OVERWRITE_EXISTING_CUTOUTS or (not exists_before)
        if force_prepare:
            log_progress(f"  → Downloading and preparing {year}...")
        _ = config.get_case_cutout(
            year=year,
            force_prepare=force_prepare,
            base_dir="data",
            case_name=CASE_NAME,
            bounds=lock_bounds,
            nodes_df=nodes_df,
            dx=lock_dx,
            dy=lock_dy,
        )
        log_progress(f"  ✓ Completed {year}")

    if cutout_file.exists():
        if exists_before:
            existing.append(year)
        else:
            created.append(year)
    else:
        missing.append(year)

log_progress(f"All years processed")
print(f"Existing cutouts: {existing}")
print(f"Created now: {created}")
print(f"Missing cutouts: {missing}")

if missing and not GENERATE_CUTOUTS:
    print("\nSome cutouts are missing. Set GENERATE_CUTOUTS = True and run this cell once.")
# Out:
# [0.0s] Starting cutout generation for 15 years
# [0.0s] Processing year 2000 (1/15)
# [0.0s]   → Downloading and preparing 2000...
# daf65546c14c7a8df3298828aed34458.grib:   0%|          | 0.00/99.0M [00:00<?, ?B/s]
# 21b48d1eb3d5b582a2f00ed9f6749506.grib:   0%|          | 0.00/3.11k [00:00<?, ?B/s]
# e60558aa9954abfc41c07d3ea8faa71d.grib:   0%|          | 0.00/54.2M [00:00<?, ?B/s]
# 783a747e17b7c61418f0e4195c4f6a11.grib:   0%|          | 0.00/18.1M [00:00<?, ?B/s]
# 70a2a07421e90952a5e9178f3325bbaa.grib:   0%|          | 0.00/72.3M [00:00<?, ?B/s]
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# [7017.3s]   ✓ Completed 2000
# [7017.3s] Processing year 2001 (2/15)
# [7017.3s]   → Downloading and preparing 2001...
# 181d5a1db201517f84a1d3bec998f4d3.grib:   0%|          | 0.00/98.7M [00:00<?, ?B/s]
# 9f5433c8ce0af43fc54a6f027d175cae.grib:   0%|          | 0.00/18.0M [00:00<?, ?B/s]
# 528802b69733c2312b61a6b9f0c66059.grib:   0%|          | 0.00/72.1M [00:00<?, ?B/s]
# aec3212ba7a282caff1c6905635bd4d3.grib:   0%|          | 0.00/3.11k [00:00<?, ?B/s]
# 6431be03ccc565e89ddba9193bc81cde.grib:   0%|          | 0.00/54.1M [00:00<?, ?B/s]
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# [15603.6s]   ✓ Completed 2001
# [15603.6s] Processing year 2002 (3/15)
# [15603.6s]   → Downloading and preparing 2002...
# 613c818d8a6197607be906b51ff65ffb.grib:   0%|          | 0.00/54.1M [00:00<?, ?B/s]
# Recovering from HTTP error [502 Bad Gateway], attempt 1 of 500
# Retrying in 120 seconds
# b1b54a7471fd9be50903bf8e7974c8c2.grib:   0%|          | 0.00/3.11k [00:00<?, ?B/s]
# 107f7427054183f72c7aea6b69dfc0de.grib:   0%|          | 0.00/98.7M [00:00<?, ?B/s]
# bb8571fb4b57b25d8e7260085ea38fd2.grib:   0%|          | 0.00/72.1M [00:00<?, ?B/s]
# 84f6f765ab94db4178adf263033541f8.grib:   0%|          | 0.00/18.0M [00:00<?, ?B/s]
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# [23731.6s]   ✓ Completed 2002
# [23731.6s] Processing year 2003 (4/15)
# [23731.6s]   → Downloading and preparing 2003...
# de6c6bbec1bacc03228ca414b5298387.grib:   0%|          | 0.00/98.7M [00:00<?, ?B/s]
# 30243014608a4f147748714e46cbfeda.grib:   0%|          | 0.00/54.1M [00:00<?, ?B/s]
# 237ee21ec74f9dbb27ece72c7c1e9a2d.grib:   0%|          | 0.00/3.11k [00:00<?, ?B/s]
# 1f60d9f166e087e1125f3b1867f58c23.grib:   0%|          | 0.00/72.1M [00:00<?, ?B/s]
# 596e3a647b929f814030ee8569a10d1e.grib:   0%|          | 0.00/18.0M [00:00<?, ?B/s]
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# [39359.9s]   ✓ Completed 2003
# [39359.9s] Processing year 2004 (5/15)
# [39359.9s]   → Downloading and preparing 2004...
# 87958d6566b3441a8df5429ae4c9d0fc.grib:   0%|          | 0.00/54.2M [00:00<?, ?B/s]
# 442f30bf74b8b6fba1f57c6dbd43bfc9.grib:   0%|          | 0.00/18.1M [00:00<?, ?B/s]
# 9d9fa0fa14f288d7430c43b8eec80216.grib:   0%|          | 0.00/99.0M [00:00<?, ?B/s]
# e331cc6e3bb6102c3334961dc5330dcf.grib:   0%|          | 0.00/3.11k [00:00<?, ?B/s]
# edaa154977fdb5f00aedca08e21eb662.grib:   0%|          | 0.00/72.3M [00:00<?, ?B/s]
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# [92412.8s]   ✓ Completed 2004
# [92412.8s] Processing year 2005 (6/15)
# [92412.8s]   → Downloading and preparing 2005...
# 555e7420f9ec92de14797221bfd4935d.grib:   0%|          | 0.00/72.1M [00:00<?, ?B/s]
# 44987e831d319273250cbf50fc254ff0.grib:   0%|          | 0.00/18.0M [00:00<?, ?B/s]
# 7b785b0a68836a3f31abb4ccf7ac5c7b.grib:   0%|          | 0.00/3.11k [00:00<?, ?B/s]
# 5d2d49c8395ba0331efb689f9be3d218.grib:   0%|          | 0.00/98.7M [00:00<?, ?B/s]
# e7d58ea0a67e82c0d5f8df7db68b9a01.grib:   0%|          | 0.00/54.1M [00:00<?, ?B/s]
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# [128670.4s]   ✓ Completed 2005
# [128670.4s] Processing year 2006 (7/15)
# [128670.4s]   → Downloading and preparing 2006...
# 122db398dfbd7adbc4125108dbd8a0dc.grib:   0%|          | 0.00/98.7M [00:00<?, ?B/s]
# d0c6bec318e3fd3d2f8852e4f946dbcd.grib:   0%|          | 0.00/54.1M [00:00<?, ?B/s]
# b8f05b4f6461e3cab2f25aebad7c9082.grib:   0%|          | 0.00/3.11k [00:00<?, ?B/s]
# 9e1d9e25d55a9449c1577595b0d7de2.grib:   0%|          | 0.00/72.1M [00:00<?, ?B/s]
# 9fccd7a57d08647723f818847e0284dc.grib:   0%|          | 0.00/18.0M [00:00<?, ?B/s]
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:250: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = cutout.data.merge(ds[missing_vars.values]).assign_attrs(**attrs)
# [158346.8s]   ✓ Completed 2006
# [158346.8s] Processing year 2007 (8/15)
# [158346.8s]   → Downloading and preparing 2007...
# 2b74c0a82273a12c03c7ec0ac9d13dc.grib:   0%|          | 0.00/72.1M [00:00<?, ?B/s]
# 2aa2e07e799ef5778fcd0276cee8d4b1.grib:   0%|          | 0.00/18.0M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 17
#      13     if GENERATE_CUTOUTS:
#      14         force_prepare = OVERWRITE_EXISTING_CUTOUTS or (not exists_before)
#      15         if force_prepare:
#      16             log_progress(f"  → Downloading and preparing {year}...")
# ---> 17         _ = config.get_case_cutout(
#      18             year=year,
#      19             force_prepare=force_prepare,
#      20             base_dir="data",
#
# File c:\Users\vse23\OneDrive - University of Canterbury\Vicente\Analysis\0_PyPSA-Isolated\model\config.py:1732, in get_case_cutout(year, force_prepare, base_dir, case_name, cutout_file, bounds, nodes_df, dx, dy)
#    1721 cutout = atlite.Cutout(
#    1722     path=cutout_path,
#    1723     module="era5",
#    (...)   1728     dy=dy,
#    1729 )
#    1731 if force_prepare or not cutout_path.exists():
# -> 1732     cutout.prepare()
#    1734 return cutout
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:124, in maybe_remove_tmpdir.<locals>.wrapper(*args, **kwargs)
#     122 kwargs["tmpdir"] = mkdtemp()
#     123 try:
# --> 124     res = func(*args, **kwargs)
#     125 finally:
#     126     rmtree(kwargs["tmpdir"])
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:230, in cutout_prepare(cutout, features, tmpdir, data_format, overwrite, compression, show_progress, dask_kwargs, monthly_requests, concurrent_requests)
#     228 logger.info(f"Calculating and writing with module {module}:")
#     229 missing_features = missing_vars.index.unique("feature")
# --> 230 ds = get_features(
#     231     cutout,
#     232     module,
#     233     missing_features,
#     234     tmpdir=tmpdir,
#     235     data_format=data_format,
#     236     monthly_requests=monthly_requests,
#     237     concurrent_requests=concurrent_requests,
#     238 )
#     239 prepared |= set(missing_features)
#     241 cutout.data.attrs.update(dict(prepared_features=list(prepared)))
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\data.py:60, in get_features(cutout, module, features, data_format, tmpdir, monthly_requests, concurrent_requests)
#      48     feature_data = delayed(get_data)(
#      49         cutout,
#      50         feature,
#    (...)     56         **parameters,
#      57     )
#      58     datasets.append(feature_data)
# ---> 60 datasets = compute(*datasets)
#      62 ds = xr.merge(datasets, compat="equals")
#      63 for v in ds:
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\dask\base.py:685, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     682     expr = expr.optimize()
#     683     keys = list(flatten(expr.__dask_keys__()))
# --> 685     results = schedule(expr, keys, **kwargs)
#     687 return repack(results)
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\datasets\era5.py:590, in get_data(cutout, feature, tmpdir, lock, data_format, monthly_requests, concurrent_requests, **creation_parameters)
#     587     return ds
#     589 if feature in static_features:
# --> 590     return retrieve_once(retrieval_times(coords, static=True)).squeeze()
#     592 time_chunks = retrieval_times(coords, monthly_requests=monthly_requests)
#     593 if concurrent_requests:
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\datasets\era5.py:584, in get_data.<locals>.retrieve_once(time)
#     583 def retrieve_once(time):
# --> 584     ds = func({**retrieval_params, **time})
#     585     if sanitize and sanitize_func is not None:
#     586         ds = sanitize_func(ds)
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\datasets\era5.py:251, in get_data_height(retrieval_params)
#     247 def get_data_height(retrieval_params):
#     248     """
#     249     Get height data for given retrieval parameters.
#     250     """
# --> 251     ds = retrieve_data(variable="geopotential", **retrieval_params)
#     253     ds = _rename_and_clean_coords(ds)
#     254     ds = _add_height(ds)
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\datasets\era5.py:492, in retrieve_data(product, chunks, tmpdir, lock, **updates)
#     487 logger.debug(f"Requesting {product} with API request: {request}")
#     489 client = cdsapi.Client(
#     490     info_callback=logger.debug, debug=logging.DEBUG >= logging.root.level
#     491 )
# --> 492 result = client.retrieve(product, request)
#     494 if lock is None:
#     495     lock = nullcontext()
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\ecmwf\datastores\legacy_client.py:167, in LegacyClient.retrieve(self, name, request, target)
#     165 submitted: datastores.Remote | datastores.Results
#     166 if self.wait_until_complete:
# --> 167     submitted = self.client.submit_and_wait_on_results(
#     168         collection_id=name,
#     169         request=request,
#     170     )
#     171 else:
#     172     submitted = self.client.submit(
#     173         collection_id=name,
#     174         request=request,
#     175     )
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\ecmwf\datastores\client.py:430, in Client.submit_and_wait_on_results(self, collection_id, request)
#     414 def submit_and_wait_on_results(
#     415     self, collection_id: str, request: dict[str, Any]
#     416 ) -> datastores.Results:
#     417     """Submit a request and wait for the results to be ready.
#     418
#     419     Parameters
#    (...)    428     datastores.Results
#     429     """
# --> 430     return self._retrieve_api.submit(collection_id, request).get_results()
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\ecmwf\datastores\processing.py:495, in Remote.get_results(self)
#     488 def get_results(self) -> Results:
#     489     """Retrieve results.
#     490
#     491     Returns
#     492     -------
#     493     datastores.Results
#     494     """
# --> 495     return self._make_results(wait=True)
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\ecmwf\datastores\processing.py:479, in Remote._make_results(self, wait)
#     477 def _make_results(self, wait: bool) -> Results:
#     478     if wait:
# --> 479         self._wait_on_results()
#     480     response = self._get_api_response("get")
#     481     try:
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\ecmwf\datastores\processing.py:457, in Remote._wait_on_results(self)
#     455 def _wait_on_results(self) -> None:
#     456     sleep = 1.0
# --> 457     while not self.results_ready:
#     458         self.debug(f"results not ready, waiting for {sleep} seconds")
#     459         time.sleep(sleep)
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\ecmwf\datastores\processing.py:471, in Remote.results_ready(self)
#     469     return False
#     470 if status in ("failed", "rejected"):
# --> 471     results = self._make_results(wait=False)
#     472     raise ProcessingFailedError(error_json_to_message(results._json_dict))
#     473 if status in ("dismissed", "deleted"):
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\ecmwf\datastores\processing.py:485, in Remote._make_results(self, wait)
#     483 except LinkError:
#     484     results_url = f"{self.url}/results"
# --> 485 results = Results.from_request("get", results_url, **self._request_kwargs)
#     486 return results
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\ecmwf\datastores\processing.py:176, in ApiResponse.from_request(cls, method, url, headers, session, retry_options, request_options, download_options, sleep_max, cleanup, log_callback, log_messages, **kwargs)
#     171 response = robust_request(
#     172     method, url, headers=headers, **request_options, **kwargs
#     173 )
#     174 log(logging.DEBUG, f"REPLY {response.text}", callback=log_callback)
# --> 176 cads_raise_for_status(response)
#     178 self = cls(
#     179     response,
#     180     headers=headers,
#    (...)    187     log_callback=log_callback,
#     188 )
#     189 if log_messages:
#
# File c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\ecmwf\datastores\processing.py:99, in cads_raise_for_status(response)
#      92     else:
#      93         message = "\n".join(
#      94             [
#      95                 f"{response.status_code} Client Error: {response.reason} for url: {response.url}",
#      96                 error_json_to_message(error_json),
#      97             ]
#      98         )
# ---> 99         raise requests.HTTPError(message, response=response)
#     100 response.raise_for_status()
#
# HTTPError: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/9149b983-95b3-4091-8956-22c936053542/results
# The job has failed

# %%
summary_rows = []
zone_rows = []

for year in YEARS:
    cutout_file = DATA_DIR / f"{CASE_NAME}_{year}.nc"
    if not cutout_file.exists():
        continue

    cutout = config.get_case_cutout(
        year=year,
        force_prepare=False,
        base_dir="data",
        case_name=CASE_NAME,
        bounds=lock_bounds,
        nodes_df=nodes_df,
        dx=lock_dx,
        dy=lock_dy,
    )

    wind_cf, solar_cf = config.get_vre_profiles_from_cutout(
        cutout=cutout,
        nodes_df=nodes_df,
        method=VRE_METHOD,
        wind_turbine=WIND_TURBINE,
        solar_panel=SOLAR_PANEL,
        solar_orientation=SOLAR_ORIENTATION,
    )

    summary_rows.append({
        "year": year,
        "hours": len(wind_cf),
        "wind_cf_mean_system": float(wind_cf.mean().mean()),
        "solar_cf_mean_system": float(solar_cf.mean().mean()),
    })

    for zone in wind_cf.columns:
        zone_rows.append({
            "year": year,
            "zone": zone,
            "wind_cf_mean": float(wind_cf[zone].mean()),
            "solar_cf_mean": float(solar_cf[zone].mean()),
        })

summary_df = pd.DataFrame(summary_rows).sort_values("year").reset_index(drop=True)
zone_df = pd.DataFrame(zone_rows).sort_values(["year", "zone"]).reset_index(drop=True)

if summary_df.empty:
    raise RuntimeError("No cutouts available to compute capacity factors.")

summary_csv = DATA_DIR / f"{CASE_NAME}_cf_summary_2016_2025.csv"
zone_csv = DATA_DIR / f"{CASE_NAME}_cf_by_zone_2016_2025.csv"
summary_df.to_csv(summary_csv, index=False)
zone_df.to_csv(zone_csv, index=False)

print(f"Saved: {summary_csv}")
print(f"Saved: {zone_csv}")
display(summary_df)
display(zone_df.head(20))
# Out:
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\cutout.py:156: UserWarning: Arguments module, x, y, time, dx, dy are ignored, since cutout is already built.
#   warn(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\cutout.py:156: UserWarning: Arguments module, x, y, time, dx, dy are ignored, since cutout is already built.
#   warn(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\cutout.py:156: UserWarning: Arguments module, x, y, time, dx, dy are ignored, since cutout is already built.
#   warn(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\cutout.py:156: UserWarning: Arguments module, x, y, time, dx, dy are ignored, since cutout is already built.
#   warn(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\cutout.py:156: UserWarning: Arguments module, x, y, time, dx, dy are ignored, since cutout is already built.
#   warn(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\cutout.py:156: UserWarning: Arguments module, x, y, time, dx, dy are ignored, since cutout is already built.
#   warn(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\cutout.py:156: UserWarning: Arguments module, x, y, time, dx, dy are ignored, since cutout is already built.
#   warn(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\cutout.py:156: UserWarning: Arguments module, x, y, time, dx, dy are ignored, since cutout is already built.
#   warn(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\cutout.py:156: UserWarning: Arguments module, x, y, time, dx, dy are ignored, since cutout is already built.
#   warn(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\cutout.py:156: UserWarning: Arguments module, x, y, time, dx, dy are ignored, since cutout is already built.
#   warn(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:739: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# c:\Users\vse23\AppData\Local\anaconda3\envs\pypsa-isolated\Lib\site-packages\atlite\convert.py:929: FutureWarning: aggregate_time='legacy' is deprecated and will be removed in a future release. Pass 'sum', 'mean', or None explicitly.
#   return cutout.convert_and_aggregate(
# Saved: data\magallanes_cf_summary_2016_2025.csv
# Saved: data\magallanes_cf_by_zone_2016_2025.csv
#    year  hours  wind_cf_mean_system  solar_cf_mean_system
# 0  2016   8784             0.500020              0.131517
# 1  2017   8760             0.538505              0.128706
# 2  2018   8760             0.532833              0.131217
# 3  2019   8760             0.541609              0.129814
# 4  2020   8784             0.519461              0.122802
# 5  2021   8760             0.563112              0.128109
# 6  2022   8760             0.559219              0.132089
# 7  2023   8760             0.581050              0.135334
# 8  2024   8784             0.534392              0.125450
# 9  2025   8760             0.540015              0.131405
#     year            zone  wind_cf_mean  solar_cf_mean
# 0   2016  punta_arenas_1      0.500020       0.131517
# 1   2016  punta_arenas_2      0.500020       0.131517
# 2   2017  punta_arenas_1      0.538505       0.128706
# 3   2017  punta_arenas_2      0.538505       0.128706
# 4   2018  punta_arenas_1      0.532833       0.131217
# 5   2018  punta_arenas_2      0.532833       0.131217
# 6   2019  punta_arenas_1      0.541609       0.129814
# 7   2019  punta_arenas_2      0.541609       0.129814
# 8   2020  punta_arenas_1      0.519461       0.122802
# 9   2020  punta_arenas_2      0.519461       0.122802
# 10  2021  punta_arenas_1      0.563112       0.128109
# 11  2021  punta_arenas_2      0.563112       0.128109
# 12  2022  punta_arenas_1      0.559219       0.132089
# 13  2022  punta_arenas_2      0.559219       0.132089
# 14  2023  punta_arenas_1      0.581050       0.135334
# 15  2023  punta_arenas_2      0.581050       0.135334
# 16  2024  punta_arenas_1      0.534392       0.125450
# 17  2024  punta_arenas_2      0.534392       0.125450
# 18  2025  punta_arenas_1      0.540015       0.131405
# 19  2025  punta_arenas_2      0.540015       0.131405

# %%
plt.figure(figsize=(10, 5))
plt.plot(summary_df["year"], summary_df["wind_cf_mean_system"], marker="o", label="Wind CF (system mean)")
plt.plot(summary_df["year"], summary_df["solar_cf_mean_system"], marker="o", label="Solar CF (system mean)")
plt.title(f"{CASE_NAME}: annual wind/solar capacity factors (2016-2025)")
plt.xlabel("Year")
plt.ylabel("Capacity factor [-]")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
